# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import SGD, Adam
from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR
from torch.utils.data import Dataset, DataLoader

from torchvision.datasets import CIFAR10
from torchvision.models import resnet18, resnet34, resnet50
import torchvision.transforms as transforms
from torchsummary import summary

import numpy as np
import time

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from medmnist import PathMNIST

from eqCLR.eq_resnet import EqResNet18

# %%
###################### PARAMS ##############################

BACKBONE = "resnet18"

BATCH_SIZE = 512
N_EPOCHS = 100 # 1000
N_CPU_WORKERS = 16
BASE_LR = 0.03         # important
WEIGHT_DECAY = 5e-4    # important
MOMENTUM = 0.9
PROJECTOR_HIDDEN_SIZE = 1024
PROJECTOR_OUTPUT_SIZE = 128
CROP_LOW_SCALE = 0.2
GRAYSCALE_PROB = 0.1   # important
PRINT_EVERY_EPOCHS = 5

MODEL_FILENAME = f"path_mnist-{BACKBONE}_wo_rotation-{np.random.randint(10000):04}.pt"

# %%
###################### DATA LOADER #########################

pmnist_train = PathMNIST(split='train', download=False, size=28, root='data/pathmnist/', transform=transforms.ToTensor())
pmnist_test = PathMNIST(split='test', download=False, size=28, root='data/pathmnist/', transform=transforms.ToTensor())

print("Data loaded.")

# additional rotation
class RandomRightAngleRotation:
    """Randomly rotate PIL image by 90, 180, or 270 degrees."""
    def __call__(self, x):
        angle = int(torch.randint(1, 4, ()).item()) * 90
        return x.rotate(angle)

transforms_ssl = transforms.Compose(
    [
        transforms.RandomResizedCrop(size=32, scale=(CROP_LOW_SCALE, 1)),
        # RandomRightAngleRotation(), # additional rotation
        transforms.RandomHorizontalFlip(),
        transforms.RandomApply(
            [transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8
        ),
        transforms.RandomGrayscale(p=GRAYSCALE_PROB),
        transforms.ToTensor(), # NB: runtime faster when this line is last
    ]
)

class PairedTransform:
    def __init__(self, transform):
        self.transform = transform

    def __call__(self, x):
        return (self.transform(x), self.transform(x))


paired_ssl_transforms = PairedTransform(transforms_ssl)

pmnist_train_ssl = PathMNIST(split='train', download=False, size=28, root='data/pathmnist/', transform=paired_ssl_transforms)

pmnist_loader_ssl = DataLoader(
    pmnist_train_ssl,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=N_CPU_WORKERS,
    pin_memory=True,
)

###################### NETWORK ARCHITECTURE #########################

class ResNetwithProjector(nn.Module):
    def __init__(self, backbone_network):
        super().__init__()

        self.backbone = backbone_network(weights=None)
        self.backbone_output_dim = self.backbone.fc.in_features
        
        self.backbone.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.backbone.maxpool = nn.Identity()
        self.backbone.fc = nn.Identity()

        self.projector = nn.Sequential(
            nn.Linear(self.backbone_output_dim, PROJECTOR_HIDDEN_SIZE), 
            nn.ReLU(), 
            nn.Linear(PROJECTOR_HIDDEN_SIZE, PROJECTOR_OUTPUT_SIZE),
        )

    def forward(self, x):
        h = self.backbone(x)
        z = self.projector(h)
        return h, z


def infoNCE(features, temperature=0.5):
    x = F.normalize(features)
    cos_xx = x @ x.T / temperature
    cos_xx.fill_diagonal_(float("-inf"))
    
    batch_size = cos_xx.size(0) // 2
    targets = torch.arange(batch_size * 2, dtype=int, device=cos_xx.device)
    targets[:batch_size] += batch_size
    targets[batch_size:] -= batch_size

    return F.cross_entropy(cos_xx, targets)

backbones = {
   "resnet18": resnet18,    # backbone_output_dim = 512
   "resnet34": resnet34,    # backbone_output_dim = 512
   "resnet50": resnet50,    # backbone_output_dim = 2048
}
# Out:
# Data loaded.

# %% [markdown]
# # SimCLR

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_resnet18 = ResNetwithProjector(backbones[BACKBONE]).to(device)
model_resnet18_wo_rotation = ResNetwithProjector(backbones[BACKBONE]).to(device)

# %%
summary(model_resnet18, input_size=(3, 28, 28),  device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 28, 28]           1,728
#        BatchNorm2d-2           [-1, 64, 28, 28]             128
#               ReLU-3           [-1, 64, 28, 28]               0
#           Identity-4           [-1, 64, 28, 28]               0
#             Conv2d-5           [-1, 64, 28, 28]          36,864
#        BatchNorm2d-6           [-1, 64, 28, 28]             128
#               ReLU-7           [-1, 64, 28, 28]               0
#             Conv2d-8           [-1, 64, 28, 28]          36,864
#        BatchNorm2d-9           [-1, 64, 28, 28]             128
#              ReLU-10           [-1, 64, 28, 28]               0
#        BasicBlock-11           [-1, 64, 28, 28]               0
#            Conv2d-12           [-1, 64, 28, 28]          36,864
#       BatchNorm2d-13           [-1, 64, 28, 28]             128
#              ReLU-14           [-1, 64, 28, 28]               0
#            Conv2d-15           [-1, 64, 28, 28]          36,864
#       BatchNorm2d-16           [-1, 64, 28, 28]             128
#              ReLU-17           [-1, 64, 28, 28]               0
#        BasicBlock-18           [-1, 64, 28, 28]               0
#            Conv2d-19          [-1, 128, 14, 14]          73,728
#       BatchNorm2d-20          [-1, 128, 14, 14]             256
#              ReLU-21          [-1, 128, 14, 14]               0
#            Conv2d-22          [-1, 128, 14, 14]         147,456
#       BatchNorm2d-23          [-1, 128, 14, 14]             256
#            Conv2d-24          [-1, 128, 14, 14]           8,192
#       BatchNorm2d-25          [-1, 128, 14, 14]             256
#              ReLU-26          [-1, 128, 14, 14]               0
#        BasicBlock-27          [-1, 128, 14, 14]               0
#            Conv2d-28          [-1, 128, 14, 14]         147,456
#       BatchNorm2d-29          [-1, 128, 14, 14]             256
#              ReLU-30          [-1, 128, 14, 14]               0
#            Conv2d-31          [-1, 128, 14, 14]         147,456
#       BatchNorm2d-32          [-1, 128, 14, 14]             256
#              ReLU-33          [-1, 128, 14, 14]               0
#        BasicBlock-34          [-1, 128, 14, 14]               0
#            Conv2d-35            [-1, 256, 7, 7]         294,912
#       BatchNorm2d-36            [-1, 256, 7, 7]             512
#              ReLU-37            [-1, 256, 7, 7]               0
#            Conv2d-38            [-1, 256, 7, 7]         589,824
#       BatchNorm2d-39            [-1, 256, 7, 7]             512
#            Conv2d-40            [-1, 256, 7, 7]          32,768
#       BatchNorm2d-41            [-1, 256, 7, 7]             512
#              ReLU-42            [-1, 256, 7, 7]               0
#        BasicBlock-43            [-1, 256, 7, 7]               0
#            Conv2d-44            [-1, 256, 7, 7]         589,824
#       BatchNorm2d-45            [-1, 256, 7, 7]             512
#              ReLU-46            [-1, 256, 7, 7]               0
#            Conv2d-47            [-1, 256, 7, 7]         589,824
#       BatchNorm2d-48            [-1, 256, 7, 7]             512
#              ReLU-49            [-1, 256, 7, 7]               0
#        BasicBlock-50            [-1, 256, 7, 7]               0
#            Conv2d-51            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-52            [-1, 512, 4, 4]           1,024
#              ReLU-53            [-1, 512, 4, 4]               0
#            Conv2d-54            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-55            [-1, 512, 4, 4]           1,024
#            Conv2d-56            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-57            [-1, 512, 4, 4]           1,024
#              ReLU-58            [-1, 512, 4, 4]               0
#        BasicBlock-59            [-1, 512, 4, 4]               0
#            Conv2d-60            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-61            [-1, 512, 4, 4]           1,024
#              ReLU-62            [-1, 512, 4, 4]               0
#            Conv2d-63            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-64            [-1, 512, 4, 4]           1,024
#              ReLU-65            [-1, 512, 4, 4]               0
#        BasicBlock-66            [-1, 512, 4, 4]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#          Identity-68                  [-1, 512]               0
#            ResNet-69                  [-1, 512]               0
#            Linear-70                 [-1, 1024]         525,312
#              ReLU-71                 [-1, 1024]               0
#            Linear-72                  [-1, 128]         131,200
# ================================================================
# Total params: 11,825,344
# Trainable params: 11,825,344
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.51
# Params size (MB): 45.11
# Estimated Total Size (MB): 57.63
# ----------------------------------------------------------------

# %%
print(model_resnet18)
# Out:
# ResNetwithProjector(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): Identity()
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (projector): Sequential(
#     (0): Linear(in_features=512, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=128, bias=True)
#   )
# )

# %%
model_resnet18.load_state_dict(torch.load('path_mnist-resnet18-1146.pt', weights_only=True))
model_resnet18_wo_rotation.load_state_dict(torch.load('path_mnist-resnet18_wo_rotation-7711.pt', weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # EqCLR

# %%
model_eq = EqResNet18(N=4).to(device)

summary(model_eq, input_size=(3, 28, 28),  device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
# SingleBlockBasisExpansion-1             [-1, 4, 1, 49]               0
# BlocksBasisExpansion-2                [-1, 3, 49]               0
#             R2Conv-3          [-1, 256, 14, 14]              64
#        BatchNorm3d-4        [-1, 64, 4, 14, 14]             128
#     InnerBatchNorm-5          [-1, 256, 14, 14]               0
#               ReLU-6          [-1, 256, 14, 14]               0
# PointwiseMaxPool2D-7            [-1, 256, 7, 7]               0
# SingleBlockBasisExpansion-8              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-9              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-10              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-11              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-12              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-13              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-14              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-15              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-16              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-17              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-18              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-19              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-20              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-21              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-22              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-23              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-24               [-1, 256, 9]               0
#            R2Conv-25            [-1, 256, 7, 7]               0
#       BatchNorm3d-26          [-1, 64, 4, 7, 7]             128
#    InnerBatchNorm-27            [-1, 256, 7, 7]               0
#              ReLU-28            [-1, 256, 7, 7]               0
# SingleBlockBasisExpansion-29              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-30              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-31              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-32              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-33              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-34              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-35              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-36              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-37              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-38              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-39              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-40              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-41              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-42              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-43              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-44              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-45               [-1, 256, 9]               0
#            R2Conv-46            [-1, 256, 7, 7]               0
#       BatchNorm3d-47          [-1, 64, 4, 7, 7]             128
#    InnerBatchNorm-48            [-1, 256, 7, 7]               0
#              ReLU-49            [-1, 256, 7, 7]               0
#      EqBasicBlock-50            [-1, 256, 7, 7]               0
# SingleBlockBasisExpansion-51              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-52              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-53              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-54              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-55              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-56              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-57              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-58              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-59              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-60              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-61              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-62              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-63              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-64              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-65              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-66              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-67               [-1, 256, 9]               0
#            R2Conv-68            [-1, 256, 7, 7]               0
#       BatchNorm3d-69          [-1, 64, 4, 7, 7]             128
#    InnerBatchNorm-70            [-1, 256, 7, 7]               0
#              ReLU-71            [-1, 256, 7, 7]               0
# SingleBlockBasisExpansion-72              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-73              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-74              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-75              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-76              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-77              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-78              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-79              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-80              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-81              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-82              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-83              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-84              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-85              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-86              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-87              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-88               [-1, 256, 9]               0
#            R2Conv-89            [-1, 256, 7, 7]               0
#       BatchNorm3d-90          [-1, 64, 4, 7, 7]             128
#    InnerBatchNorm-91            [-1, 256, 7, 7]               0
#              ReLU-92            [-1, 256, 7, 7]               0
#      EqBasicBlock-93            [-1, 256, 7, 7]               0
#  SequentialModule-94            [-1, 256, 7, 7]               0
# SingleBlockBasisExpansion-95              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-96              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-97              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-98              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-99              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-100              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-101              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-102              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-103              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-104              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-105              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-106              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-107              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-108              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-109              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-110              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-111               [-1, 256, 9]               0
#           R2Conv-112            [-1, 512, 4, 4]               0
#      BatchNorm3d-113         [-1, 128, 4, 4, 4]             256
#   InnerBatchNorm-114            [-1, 512, 4, 4]               0
#             ReLU-115            [-1, 512, 4, 4]               0
# SingleBlockBasisExpansion-116              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-117              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-118              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-119              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-120              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-121              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-122              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-123              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-124              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-125              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-126              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-127              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-128              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-129              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-130              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-131              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-132               [-1, 512, 9]               0
#           R2Conv-133            [-1, 512, 4, 4]               0
#      BatchNorm3d-134         [-1, 128, 4, 4, 4]             256
#   InnerBatchNorm-135            [-1, 512, 4, 4]               0
# SingleBlockBasisExpansion-136              [-1, 4, 4, 1]               0
# SingleBlockBasisExpansion-137              [-1, 4, 4, 1]               0
# SingleBlockBasisExpansion-138              [-1, 4, 4, 1]               0
# BlocksBasisExpansion-139               [-1, 256, 1]               0
#           R2Conv-140            [-1, 512, 4, 4]               0
#             ReLU-141            [-1, 512, 4, 4]               0
#     EqBasicBlock-142            [-1, 512, 4, 4]               0
# SingleBlockBasisExpansion-143              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-144              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-145              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-146              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-147              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-148              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-149              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-150              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-151              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-152              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-153              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-154              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-155              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-156              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-157              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-158              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-159               [-1, 512, 9]               0
#           R2Conv-160            [-1, 512, 4, 4]               0
#      BatchNorm3d-161         [-1, 128, 4, 4, 4]             256
#   InnerBatchNorm-162            [-1, 512, 4, 4]               0
#             ReLU-163            [-1, 512, 4, 4]               0
# SingleBlockBasisExpansion-164              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-165              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-166              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-167              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-168              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-169              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-170              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-171              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-172              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-173              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-174              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-175              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-176              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-177              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-178              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-179              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-180               [-1, 512, 9]               0
#           R2Conv-181            [-1, 512, 4, 4]               0
#      BatchNorm3d-182         [-1, 128, 4, 4, 4]             256
#   InnerBatchNorm-183            [-1, 512, 4, 4]               0
#             ReLU-184            [-1, 512, 4, 4]               0
#     EqBasicBlock-185            [-1, 512, 4, 4]               0
# SequentialModule-186            [-1, 512, 4, 4]               0
# SingleBlockBasisExpansion-187              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-188              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-189              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-190              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-191              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-192              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-193              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-194              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-195              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-196              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-197              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-198              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-199              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-200              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-201              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-202              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-203               [-1, 512, 9]               0
#           R2Conv-204           [-1, 1024, 2, 2]               0
#      BatchNorm3d-205         [-1, 256, 4, 2, 2]             512
#   InnerBatchNorm-206           [-1, 1024, 2, 2]               0
#             ReLU-207           [-1, 1024, 2, 2]               0
# SingleBlockBasisExpansion-208              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-209              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-210              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-211              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-212              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-213              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-214              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-215              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-216              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-217              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-218              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-219              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-220              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-221              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-222              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-223              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-224              [-1, 1024, 9]               0
#           R2Conv-225           [-1, 1024, 2, 2]               0
#      BatchNorm3d-226         [-1, 256, 4, 2, 2]             512
#   InnerBatchNorm-227           [-1, 1024, 2, 2]               0
# SingleBlockBasisExpansion-228              [-1, 4, 4, 1]               0
# SingleBlockBasisExpansion-229              [-1, 4, 4, 1]               0
# SingleBlockBasisExpansion-230              [-1, 4, 4, 1]               0
# BlocksBasisExpansion-231               [-1, 512, 1]               0
#           R2Conv-232           [-1, 1024, 2, 2]               0
#             ReLU-233           [-1, 1024, 2, 2]               0
#     EqBasicBlock-234           [-1, 1024, 2, 2]               0
# SingleBlockBasisExpansion-235              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-236              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-237              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-238              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-239              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-240              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-241              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-242              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-243              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-244              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-245              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-246              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-247              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-248              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-249              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-250              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-251              [-1, 1024, 9]               0
#           R2Conv-252           [-1, 1024, 2, 2]               0
#      BatchNorm3d-253         [-1, 256, 4, 2, 2]             512
#   InnerBatchNorm-254           [-1, 1024, 2, 2]               0
#             ReLU-255           [-1, 1024, 2, 2]               0
# SingleBlockBasisExpansion-256              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-257              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-258              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-259              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-260              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-261              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-262              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-263              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-264              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-265              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-266              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-267              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-268              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-269              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-270              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-271              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-272              [-1, 1024, 9]               0
#           R2Conv-273           [-1, 1024, 2, 2]               0
#      BatchNorm3d-274         [-1, 256, 4, 2, 2]             512
#   InnerBatchNorm-275           [-1, 1024, 2, 2]               0
#             ReLU-276           [-1, 1024, 2, 2]               0
#     EqBasicBlock-277           [-1, 1024, 2, 2]               0
# SequentialModule-278           [-1, 1024, 2, 2]               0
# SingleBlockBasisExpansion-279              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-280              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-281              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-282              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-283              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-284              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-285              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-286              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-287              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-288              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-289              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-290              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-291              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-292              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-293              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-294              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-295              [-1, 1024, 9]               0
#           R2Conv-296           [-1, 2048, 1, 1]               0
#      BatchNorm3d-297         [-1, 512, 4, 1, 1]           1,024
#   InnerBatchNorm-298           [-1, 2048, 1, 1]               0
#             ReLU-299           [-1, 2048, 1, 1]               0
# SingleBlockBasisExpansion-300              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-301              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-302              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-303              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-304              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-305              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-306              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-307              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-308              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-309              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-310              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-311              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-312              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-313              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-314              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-315              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-316              [-1, 2048, 9]               0
#           R2Conv-317           [-1, 2048, 1, 1]               0
#      BatchNorm3d-318         [-1, 512, 4, 1, 1]           1,024
#   InnerBatchNorm-319           [-1, 2048, 1, 1]               0
# SingleBlockBasisExpansion-320              [-1, 4, 4, 1]               0
# SingleBlockBasisExpansion-321              [-1, 4, 4, 1]               0
# SingleBlockBasisExpansion-322              [-1, 4, 4, 1]               0
# BlocksBasisExpansion-323              [-1, 1024, 1]               0
#           R2Conv-324           [-1, 2048, 1, 1]               0
#             ReLU-325           [-1, 2048, 1, 1]               0
#     EqBasicBlock-326           [-1, 2048, 1, 1]               0
# SingleBlockBasisExpansion-327              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-328              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-329              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-330              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-331              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-332              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-333              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-334              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-335              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-336              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-337              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-338              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-339              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-340              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-341              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-342              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-343              [-1, 2048, 9]               0
#           R2Conv-344           [-1, 2048, 1, 1]               0
#      BatchNorm3d-345         [-1, 512, 4, 1, 1]           1,024
#   InnerBatchNorm-346           [-1, 2048, 1, 1]               0
#             ReLU-347           [-1, 2048, 1, 1]               0
# SingleBlockBasisExpansion-348              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-349              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-350              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-351              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-352              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-353              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-354              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-355              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-356              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-357              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-358              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-359              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-360              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-361              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-362              [-1, 4, 4, 9]               0
# SingleBlockBasisExpansion-363              [-1, 4, 4, 9]               0
# BlocksBasisExpansion-364              [-1, 2048, 9]               0
#           R2Conv-365           [-1, 2048, 1, 1]               0
#      BatchNorm3d-366         [-1, 512, 4, 1, 1]           1,024
#   InnerBatchNorm-367           [-1, 2048, 1, 1]               0
#             ReLU-368           [-1, 2048, 1, 1]               0
#     EqBasicBlock-369           [-1, 2048, 1, 1]               0
# SequentialModule-370           [-1, 2048, 1, 1]               0
#     GroupPooling-371            [-1, 512, 1, 1]               0
#           Linear-372                 [-1, 1024]         525,312
#             ReLU-373                 [-1, 1024]               0
#           Linear-374                  [-1, 128]         131,200
# ================================================================
# Total params: 664,384
# Trainable params: 664,320
# Non-trainable params: 64
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.88
# Params size (MB): 2.53
# Estimated Total Size (MB): 9.43
# ----------------------------------------------------------------

# %%
print(model_eq)
# Out:
# EqResNet18(
#   (conv1): R2Conv([C4_on_R2[(None, 4)]: {irrep_0 (x3)}(3)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=7, stride=2, padding=3)
#   (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x64)}(256)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#   (maxpool): PointwiseMaxPool2D()
#   (layer1): SequentialModule(
#     (0): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x64)}(256)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x64)}(256)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x64)}(256)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x64)}(256)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x64)}(256)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x64)}(256)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): SequentialModule(
#     (0): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x128)}(512)], kernel_size=3, stride=2, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x128)}(512)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x128)}(512)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x128)}(512)], [C4_on_R2[(None, 4)]: {regular (x128)}(512)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x128)}(512)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): R2Conv([C4_on_R2[(None, 4)]: {regular (x64)}(256)], [C4_on_R2[(None, 4)]: {regular (x128)}(512)], kernel_size=1, stride=2, bias=False)
#     )
#     (1): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x128)}(512)], [C4_on_R2[(None, 4)]: {regular (x128)}(512)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x128)}(512)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x128)}(512)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x128)}(512)], [C4_on_R2[(None, 4)]: {regular (x128)}(512)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x128)}(512)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): SequentialModule(
#     (0): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x128)}(512)], [C4_on_R2[(None, 4)]: {regular (x256)}(1024)], kernel_size=3, stride=2, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x256)}(1024)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], [C4_on_R2[(None, 4)]: {regular (x256)}(1024)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): R2Conv([C4_on_R2[(None, 4)]: {regular (x128)}(512)], [C4_on_R2[(None, 4)]: {regular (x256)}(1024)], kernel_size=1, stride=2, bias=False)
#     )
#     (1): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], [C4_on_R2[(None, 4)]: {regular (x256)}(1024)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x256)}(1024)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], [C4_on_R2[(None, 4)]: {regular (x256)}(1024)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): SequentialModule(
#     (0): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], [C4_on_R2[(None, 4)]: {regular (x512)}(2048)], kernel_size=3, stride=2, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x512)}(2048)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x512)}(2048)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x512)}(2048)], [C4_on_R2[(None, 4)]: {regular (x512)}(2048)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x512)}(2048)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): R2Conv([C4_on_R2[(None, 4)]: {regular (x256)}(1024)], [C4_on_R2[(None, 4)]: {regular (x512)}(2048)], kernel_size=1, stride=2, bias=False)
#     )
#     (1): EqBasicBlock(
#       (conv1): R2Conv([C4_on_R2[(None, 4)]: {regular (x512)}(2048)], [C4_on_R2[(None, 4)]: {regular (x512)}(2048)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn1): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x512)}(2048)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=False, type=[C4_on_R2[(None, 4)]: {regular (x512)}(2048)])
#       (conv2): R2Conv([C4_on_R2[(None, 4)]: {regular (x512)}(2048)], [C4_on_R2[(None, 4)]: {regular (x512)}(2048)], kernel_size=3, stride=1, padding=1, bias=False)
#       (bn2): InnerBatchNorm([C4_on_R2[(None, 4)]: {regular (x512)}(2048)], eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (gpool): GroupPooling([C4_on_R2[(None, 4)]: {regular (x512)}(2048)])
#   (fully_net): Sequential(
#     (0): Linear(in_features=512, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1024, out_features=128, bias=True)
#   )
# )

# %%
model_eq.load_state_dict(torch.load('path_mnist-eqCLR_resnet18_wo_rotation-0319.pt', weights_only=True))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 model_eq.load_state_dict(torch.load('path_mnist-eqCLR_resnet18_wo_rotation-0319.pt', weights_only=True))
#
# File ~/miniconda3/envs/eq_env2/lib/python3.12/site-packages/torch/nn/modules/module.py:2629, in Module.load_state_dict(self, state_dict, strict, assign)
#    2621         error_msgs.insert(
#    2622             0,
#    2623             "Missing key(s) in state_dict: {}. ".format(
#    2624                 ", ".join(f'"{k}"' for k in missing_keys)
#    2625             ),
#    2626         )
#    2628 if len(error_msgs) > 0:
# -> 2629     raise RuntimeError(
#    2630         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2631             self.__class__.__name__, "\n\t".join(error_msgs)
#    2632         )
#    2633     )
#    2634 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for EqResNet18:
# 	Missing key(s) in state_dict: "conv1.expanded_bias", "conv1.filter", "layer1.0.conv1.filter", "layer1.0.conv2.filter", "layer1.1.conv1.filter", "layer1.1.conv2.filter", "layer2.0.conv1.filter", "layer2.0.conv2.filter", "layer2.0.downsample.filter", "layer2.1.conv1.filter", "layer2.1.conv2.filter", "layer3.0.conv1.filter", "layer3.0.conv2.filter", "layer3.0.downsample.filter", "layer3.1.conv1.filter", "layer3.1.conv2.filter", "layer4.0.conv1.filter", "layer4.0.conv2.filter", "layer4.0.downsample.filter", "layer4.1.conv1.filter", "layer4.1.conv2.filter".
# 	size mismatch for fully_net.2.weight: copying a param with shape torch.Size([9, 1024]) from checkpoint, the shape in current model is torch.Size([128, 1024]).
# 	size mismatch for fully_net.2.bias: copying a param with shape torch.Size([9]) from checkpoint, the shape in current model is torch.Size([128]).

# %% [markdown]
# # Evaluation

# %%
def dataset_to_X_y(dataset, model):
    X = []
    y = []
    Z = []

    for batch_idx, batch in enumerate(DataLoader(dataset, batch_size=1024)):
        images, labels = batch

        h, z = model(images.to(device))

        X.append(h.cpu().numpy())
        Z.append(z.cpu().numpy())
        y.append(labels.cpu().numpy().ravel())

    X = np.vstack(X)
    Z = np.vstack(Z)
    y = np.hstack(y)

    return X, y, Z

# %%
def eval_knn(X_train, y_train, X_test, y_test):
    eval_dict = {}

    for k in [1, 5, 10]:
        for metric in ["euclidean", "cosine"]:
            knn = KNeighborsClassifier(n_neighbors=k, metric=metric, n_jobs=-1)
            knn.fit(X_train, y_train)
            acc = knn.score(X_test, y_test)
            eval_dict[metric] = {k: acc}
            print(f"KNN (k={k}, metric={metric}): {acc*100:.2f}%")

    # Logistic Regression
    logreg = LogisticRegression(max_iter=1000, n_jobs=-1)
    logreg.fit(X_train, y_train)
    log_reg = logreg.score(X_test, y_test)
    eval_dict["logistic_regression"] = log_reg
    print(f"Logistic Regression: {log_reg*100:.2f}%")

    lin = LogisticRegression(penalty=None, solver="saga")
    lin.fit(X_train, y_train)
    lin_acc = lin.score(X_test, y_test)
    eval_dict["linear_accuracy"] = lin_acc
    print(f"Linear accuracy (sklearn): {lin_acc}", flush=True)

    return eval_dict

# %%
def lin_eval_rep(X_train, y_train, X_test, y_test, n_epochs=500, adam_lr=0.01):

    X_train = torch.tensor(X_train, device=device)
    X_test = torch.tensor(X_test, device=device)
    y_train = torch.tensor(y_train, device=device)
    y_test = torch.tensor(y_test, device=device)

    classifier = nn.Linear(X_train.shape[1], 10)
    classifier.to(device)
    classifier.train()

    optimizer = Adam(classifier.parameters(), lr=adam_lr)
    scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs)

    for epoch in range(n_epochs):
        N = len(X_train)
        perm = torch.randperm(N)
        perm = perm[:N - (N % 1000)]              # drop remainder
        batches = perm.view(-1, 1000)        
        for idx in batches:
            optimizer.zero_grad()
            logits = classifier(X_train[idx])
            loss = F.cross_entropy(logits, y_train[idx])
            loss.backward()
            optimizer.step()
        scheduler.step()

    classifier.eval()
    with torch.no_grad():
        yhat = classifier(X_test)

    acc = (yhat.argmax(axis=1) == y_test).cpu().numpy().mean()
    print(f"Linear accuracy (Adam on precomputed representations): {acc}", flush=True)

    return acc

# %%
def lin_eval_aug(loader_classifier, model, n_classes, n_epochs=100, adam_lr=0.01, adam_wd=5e-6):
    classifier = nn.Linear(model.backbone_output_dim, n_classes)
    for param in model.backbone.parameters():
        param.requires_grad = False

    optimizer = Adam(classifier.parameters(), lr=adam_lr, weight_decay=adam_wd)
    scheduler = CosineAnnealingLR(optimizer, T_max=n_epochs)

    classifier.to(device)
    classifier.train()
    training_start_time = time.time()

    for epoch in range(n_epochs):
        epoch_loss = 0.0
        start_time = time.time()

        for batch_idx, batch in enumerate(loader_classifier):
            view, y = batch

            optimizer.zero_grad()

            h, _ = model(view.to(device))
            logits = classifier(h)
            loss = F.cross_entropy(logits, y.to(device).squeeze().long())
            epoch_loss += loss.item()

            loss.backward()
            optimizer.step()

        end_time = time.time()
        if (epoch + 1) % PRINT_EVERY_EPOCHS == 0:
            print(
                f"Epoch {epoch + 1}, "
                f"average loss {epoch_loss / len(loader_classifier):.4f}, "
                f"{end_time - start_time:.1f} s",
                flush=True
            )

    scheduler.step()

    training_end_time = time.time()
    hours = (training_end_time - training_start_time) / 60 // 60
    minutes = (training_end_time - training_start_time) / 60 % 60
    print(
        f"Total classifier training length for {n_epochs} epochs: {hours:.0f}h {minutes:.0f}min",
        flush=True
    )

    classifier.eval()
    with torch.no_grad():
        yhat = []
        y = []

        for batch_idx, batch in enumerate(DataLoader(pmnist_test, batch_size=1024)):
            images, labels = batch

            h, _ = model(images.to(device))
            logits = classifier(h)

            yhat.append(logits.cpu().numpy())
            y.append(labels)

        yhat = np.vstack(yhat)
        y = np.hstack(y)

    acc = (yhat.argmax(axis=1) == y).mean()
    print(f"Linear accuracy (trained with augmentations): {acc}", flush=True)

    return acc

# %% [markdown]
# ## SimCLR

# %% [markdown]
# ### With rotation (default)

# %%
with torch.no_grad():
    X_train, y_train, Z_train = dataset_to_X_y(pmnist_train, model_resnet18)
    X_test, y_test, Z_test = dataset_to_X_y(pmnist_test, model_resnet18)

# %%
resnet_18_eval = eval_knn(X_train, y_train, X_test, y_test)
# Out:
# KNN (k=1, metric=euclidean): 84.53%
# KNN (k=1, metric=cosine): 84.48%
# KNN (k=5, metric=euclidean): 87.06%
# KNN (k=5, metric=cosine): 86.96%
# KNN (k=10, metric=euclidean): 87.58%
# KNN (k=10, metric=cosine): 87.30%
# Logistic Regression: 90.56%
# Linear accuracy (sklearn): 0.9036211699164345
# /gpfs01/berens/user/nkury/miniconda3/envs/eq_env2/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
evaaal = lin_eval_rep(X_train, y_train, X_test, y_test)
# Out:
# Linear accuracy (Adam on precomputed representations): 0.8998607242339833

# %%
transforms_classifier = transforms.Compose(
    [
        transforms.RandomResizedCrop(size=32, scale=(CROP_LOW_SCALE, 1)),
        transforms.RandomHorizontalFlip(),
        RandomRightAngleRotation(), # additional rotation
        transforms.ToTensor(),
    ]
)

pmnist_train_classifier = PathMNIST(split='train', download=False, size=28, root='data/pathmnist/', transform=transforms_classifier)


pmnist_loader_classifier = DataLoader(
    pmnist_train_classifier,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=N_CPU_WORKERS,
)

# %%
evaaaaaaal = eval_lin_aug = lin_eval_aug(pmnist_loader_classifier, model_resnet18, n_classes=9)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 evaaaaaaal = eval_lin_aug = lin_eval_aug(pmnist_loader_classifier, model_resnet18, n_classes=9)
#
# Cell In[54], line 24, in lin_eval_aug(loader_classifier, model, n_classes, n_epochs, adam_lr, adam_wd)
#      22 h, _ = model(view.to(device))
#      23 logits = classifier(h)
# ---> 24 loss = F.cross_entropy(logits, y.to(device).squeeze().long())
#      25 epoch_loss += loss.item()
#      27 loss.backward()
#
# KeyboardInterrupt:
