# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import SGD, Adam
from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR
from torch.utils.data import Dataset, DataLoader

from torchvision.datasets import CIFAR10
from torchvision.models import resnet18, resnet34, resnet50
import torchvision.transforms as transforms
from torchsummary import summary

import numpy as np
import time
import pickle
import pandas as pd
import re
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from medmnist import PathMNIST

from eqCLR.eq_resnet import EqResNet18, Mixed_EqResnet18
from eqCLR.test_resnet import Wide_ResNet
from evaluation import model_eval, dataset_to_X_y, lin_eval_rep

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# 2026-01-08 12:35:03.091869: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-08 12:35:03.164293: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-08 12:35:35.698397: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
class RandomRightAngleRotation:
    """Randomly rotate PIL image by 90, 180, or 270 degrees."""
    def __call__(self, x):
        angle = int(torch.randint(1, 4, ()).item()) * 90
        return x.rotate(angle)

# %%
# Simclr
with open('results/model_eval/2105-path_mnist-resnet18_with_maxpool_lr03_frac1.0_eval.pkl', 'rb') as f:
    eval_resnet18_100 = pickle.load(f)

with open('results/model_eval/2105-path_mnist-resnet18_with_maxpool_lr03_frac0.8_eval.pkl', 'rb') as f:
    eval_resnet18_80 = pickle.load(f)

with open('results/model_eval/2105-path_mnist-resnet18_with_maxpool_lr03_frac0.6_eval.pkl', 'rb') as f:
    eval_resnet18_60 = pickle.load(f)

with open('results/model_eval/2105-path_mnist-resnet18_with_maxpool_lr03_frac0.4_eval.pkl', 'rb') as f:
    eval_resnet18_40 = pickle.load(f)

with open('results/model_eval/2105-path_mnist-resnet18_with_maxpool_lr03_frac0.2_eval.pkl', 'rb') as f:
    eval_resnet18_20 = pickle.load(f)

# %%
with open('results/model_details/2105-path_mnist-resnet18_with_maxpool_lr03_frac1.0_details.pkl', 'rb') as f:
    details_resnet18_100 = pickle.load(f)

# %%
details_resnet18_100.keys()
# Out:
# dict_keys(['Filename', 'Model', 'N_EPOCHS', 'BATCH_SIZE', 'BASE_LR', 'WEIGHT_DECAY', 'MOMENTUM', 'CROP_LOW_SCALE', 'GRAYSCALE_PROB', 'PROJECTOR_HIDDEN_SIZE', 'PROJECTOR_OUTPUT_SIZE', 'Training augmentations', 'Training time', 'Training time per epoch', 'KNN during training', 'Image resize', 'Embeddings during training'])

# %%
details_resnet18_100
# Out:
# {'Filename': '2105-path_mnist-resnet18_with_maxpool_lr03',
#  'Model': 'ResNetwithProjector(\n  (backbone): ResNet(\n    (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)\n    (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n    (relu): ReLU(inplace=True)\n    (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)\n    (layer1): Sequential(\n      (0): BasicBlock(\n        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (relu): ReLU(inplace=True)\n        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n      )\n      (1): BasicBlock(\n        (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (relu): ReLU(inplace=True)\n        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n      )\n    )\n    (layer2): Sequential(\n      (0): BasicBlock(\n        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)\n        (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (relu): ReLU(inplace=True)\n        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (downsample): Sequential(\n          (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)\n          (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        )\n      )\n      (1): BasicBlock(\n        (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (relu): ReLU(inplace=True)\n        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n      )\n    )\n    (layer3): Sequential(\n      (0): BasicBlock(\n        (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)\n        (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (relu): ReLU(inplace=True)\n        (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (downsample): Sequential(\n          (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)\n          (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        )\n      )\n      (1): BasicBlock(\n        (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (relu): ReLU(inplace=True)\n        (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)\n        (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n      )\n    )\n    (layer4): Sequential(\n      (0): BasicBlock(\n        (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)\n        (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)\n        (relu): ReLU(inplace=True)\n        (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), ...
#  'N_EPOCHS': 100,
#  'BATCH_SIZE': 512,
#  'BASE_LR': 0.03,
#  'WEIGHT_DECAY': 0.0005,
#  'MOMENTUM': 0.9,
#  'CROP_LOW_SCALE': 0.2,
#  'GRAYSCALE_PROB': 0.1,
#  'PROJECTOR_HIDDEN_SIZE': 1024,
#  'PROJECTOR_OUTPUT_SIZE': 128,
#  'Training augmentations': Compose(
#      Resize(size=(28, 28), interpolation=bilinear, max_size=None, antialias=True)
#      RandomResizedCrop(size=(28, 28), scale=(0.2, 1), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=True)
#      <__main__.RandomRightAngleRotation object at 0x7fd8904e23c0>
#      RandomHorizontalFlip(p=0.5)
#      RandomApply(
#      p=0.8
#      ColorJitter(brightness=(0.6, 1.4), contrast=(0.6, 1.4), saturation=(0.6, 1.4), hue=(-0.1, 0.1))
#  )
#      RandomGrayscale(p=0.1)
#      ToTensor()
#  ),
#  'Training time': 2867.150876045227,
#  'Training time per epoch': 28.67150876045227,
#  'KNN during training': {0: 0.6225626740947076,
#   1: 0.6537604456824513,
#   2: 0.6664345403899722,
#   3: 0.6837047353760446,
#   4: 0.697075208913649,
#   5: 0.7172701949860725,
#   6: 0.7086350974930362,
#   7: 0.7272980501392757,
#   8: 0.7267409470752089,
#   9: 0.71991643454039,
#   10: 0.7405292479108635,
#   11: 0.7458217270194986,
#   12: 0.7534818941504178,
#   13: 0.7628133704735376,
#   14: 0.7607242339832869,
#   15: 0.7579387186629526,
#   16: 0.7662952646239555,
#   17: 0.7686629526462395,
#   18: 0.7789693593314764,
#   19: 0.7883008356545961,
#   20: 0.7828690807799443,
#   21: 0.7825905292479108,
#   22: 0.7889972144846796,
#   23: 0.7873259052924791,
#   24: 0.7881615598885794,
#   25: 0.7969359331476323,
#   26: 0.7885793871866296,
#   27: 0.7983286908077994,
#   28: 0.7732590529247911,
#   29: 0.8089136490250697,
#   30: 0.8059888579387187,
#   31: 0.8110027855153203,
#   32: 0.7972144846796657,
#   33: 0.800974930362117,
#   34: 0.8118384401114206,
#   35: 0.8069637883008357,
#   36: 0.8157381615598885,
#   37: 0.7979108635097493,
#   38: 0.8185236768802229,
#   39: 0.8164345403899721,
#   40: 0.8171309192200558,
#   41: 0.8238161559888579,
#   42: 0.8188022284122562,
#   43: 0.8263231197771588,
#   44: 0.8183844011142062,
#   45: 0.8232590529247911,
#   46: 0.8298050139275766,
#   47: 0.8192200557103064,
#   48: 0.8118384401114206,
#   49: 0.8313370473537605,
#   50: 0.8246518105849582,
#   51: 0.8151810584958217,
#   52: 0.8274373259052925,
#   53: 0.8292479108635098,
#   54: 0.8190807799442897,
#   55: 0.8239554317548746,
#   56: 0.8275766016713092,
#   57: 0.831058495821727,
#   58: 0.841225626740947,
#   59: 0.8298050139275766,
#   60: 0.8364902506963788,
#   61: 0.8396935933147632,
#   62: 0.8451253481894151,
#   63: 0.8399721448467966,
#   64: 0.8423398328690808,
#   65: 0.8445682451253482,
#   66: 0.8474930362116991,
#   67: 0.8224233983286908,
#   68: 0.8427576601671309,
#   69: 0.8508356545961003,
#   70: 0.8444289693593314,
#   71: 0.8335654596100278,
#   72: 0.8470752089136491,
#   73: 0.813091922005571,
#   74: 0.831058495821727,
#   75: 0.8428969359331476,
#   76: 0.8541782729805014,
#   77: 0.8456824512534818,
#   78: 0.8298050139275766,
#   79: 0.8288300835654596,
#   80: 0.8545961002785515,
#   81: 0.8512534818941504,
#   82: 0.8520891364902506,
#   83: 0.8487465181058496,
#   84: 0.8564066852367688,
#   85: 0.8547353760445683,
#   86: 0.8526462395543175,
#   87: 0.8544568245125348,
#   88: 0.8515320334261839,
#   89: 0.8564066852367688,
#   90: 0.8512534818941504,
#   91: 0.8532033426183844,
#   92: 0.8525069637883008,
#   93: 0.851949860724234,
#   94: 0.8532033426183844,
#   95: 0.854874651810585,
#   96: 0.8532033426183844,
#   97: 0.8533426183844011,
#   98: 0.852924791086351,
#   99: 0.8533426183844011},
#  'Image resize': 28,
#  'Embeddings during training': {}}

# %%
import pandas as pd

models = {
    "100%": eval_resnet18_100,
    "80%": eval_resnet18_80,
    "60%": eval_resnet18_60,
    "40%": eval_resnet18_40,
    "20%": eval_resnet18_20,
    }

eval_dict_all = {}

for model in models:
    eval_dict_all[model] = {}
    eval_dict = models[model]
    eval_dict_all[model]['KNN (k=10, euclidean)'] = eval_dict['euclidean'][10]
    eval_dict_all[model]['KNN (k=10, cosine)'] = eval_dict['cosine'][10]

    for key in eval_dict:
        if key != "cosine" and key != "euclidean" and key != 'linear_accuracy':
            eval_dict_all[model][key] = eval_dict[key]
    

evals_df_res = pd.DataFrame(eval_dict_all).T

display(evals_df_res)
# Out:
#       KNN (k=10, euclidean)  KNN (k=10, cosine)  logistic_regression  \
# 100%               0.853343            0.853900             0.870334
# 80%                0.847214            0.846240             0.859889
# 60%                0.840529            0.839136             0.842758
# 40%                0.816435            0.816295             0.828830
# 20%                0.748468            0.748607             0.791086
#
#       linear_accuracy_rep  linear_accuracy_aug
# 100%             0.868942             0.866435
# 80%              0.857103             0.850557
# 60%              0.842479             0.810446
# 40%              0.827855             0.749164
# 20%              0.794708             0.715181

# %%
# EqCLR
with open('results/model_eval/6253-path_mnist-eqCLR_N8_resize33_with_maxpool_frac1.0_eval.pkl', 'rb') as f:
    eval_eqresnet18_100 = pickle.load(f)

with open('results/model_eval/6253-path_mnist-eqCLR_N8_resize33_with_maxpool_frac0.8_eval.pkl', 'rb') as f:
    eval_eqresnet18_80 = pickle.load(f)

with open('results/model_eval/6253-path_mnist-eqCLR_N8_resize33_with_maxpool_frac_0.6_eval.pkl', 'rb') as f:
    eval_eqresnet18_60 = pickle.load(f)

with open('results/model_eval/6253-path_mnist-eqCLR_N8_resize33_with_maxpool_frac0.4_eval.pkl', 'rb') as f:
    eval_eqresnet18_40 = pickle.load(f)

with open('results/model_eval/6253-path_mnist-eqCLR_N8_resize33_with_maxpool_frac0.2_eval.pkl', 'rb') as f:
    eval_eqresnet18_20 = pickle.load(f)

# %%
import pandas as pd

models = {
    "100%": eval_eqresnet18_100,
    "80%": eval_eqresnet18_80,
    "60%": eval_eqresnet18_60,
    "40%": eval_eqresnet18_40,
    "20%": eval_eqresnet18_20,
    }

eval_dict_all = {}

for model in models:
    eval_dict_all[model] = {}
    eval_dict = models[model]
    eval_dict_all[model]['KNN (k=10, euclidean)'] = eval_dict['euclidean'][10]
    eval_dict_all[model]['KNN (k=10, cosine)'] = eval_dict['cosine'][10]

    for key in eval_dict:
        if key != "cosine" and key != "euclidean" and key != 'linear_accuracy':
            eval_dict_all[model][key] = eval_dict[key]
    

evals_df_eqres = pd.DataFrame(eval_dict_all).T

display(evals_df_eqres)
# Out:
#       KNN (k=10, euclidean)  KNN (k=10, cosine)  logistic_regression  \
# 100%               0.900000            0.899443             0.910028
# 80%                0.896518            0.895265             0.914763
# 60%                0.886908            0.888022             0.900836
# 40%                0.875487            0.879666             0.891365
# 20%                0.855850            0.858217             0.867967
#
#       linear_accuracy_rep  linear_accuracy_aug
# 100%             0.908774             0.909192
# 80%              0.913928             0.911003
# 60%              0.900696             0.887604
# 40%              0.893036             0.878552
# 20%              0.872423             0.841504

# %%
evals_df_eqres['KNN (k=10, euclidean)'].max()
# Out:
# 0.9

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,6))
size = 16

ax[0].plot(evals_df_eqres.index[::-1], evals_df_eqres['KNN (k=10, euclidean)'][::-1], marker='o', label='EqResNet18', color='orange')
ax[0].plot(evals_df_res.index[::-1], evals_df_res['KNN (k=10, euclidean)'][::-1], marker='o', label='ResNet18', color='blue')

ax[0].set_ylim(0.73, 0.91)
ax[0].tick_params(axis='both', which='major', labelsize=size-2)
ax[0].spines['left'].set_position(('outward', 10)) 

ax[0].set_xlabel("Perc. training samples", fontsize=size)
ax[0].set_ylabel("KNN Accuracy", fontsize=size)
#ax[0].legend(frameon=False, loc='lower right', fontsize=size)
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)

# KNN percentage difference plot
knn_eq = evals_df_eqres['KNN (k=10, euclidean)'] / evals_df_eqres['KNN (k=10, euclidean)'].max() * 100
knn_res = evals_df_res['KNN (k=10, euclidean)'] / evals_df_res['KNN (k=10, euclidean)'].max() * 100

ax[1].plot(evals_df_eqres.index[::-1], knn_eq[::-1], marker='o', label='EqResNet18', color='orange')
ax[1].plot(evals_df_res.index[::-1], knn_res[::-1], marker='o', label='ResNet18', color='blue')

#ax[1].set_ylim(0.73, 0.91)
ax[1].tick_params(axis='both', which='major', labelsize=size-2)
ax[1].spines['left'].set_position(('outward', 10)) 

ax[1].set_xlabel("Perc. training samples", fontsize=size)
ax[1].set_ylabel("KNN Accuracy (%)", fontsize=size)
ax[1].legend(frameon=False, loc='lower right', fontsize=size)
ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
size = 16

x_vals = ['20%', '40%', '60%', '80%', '100%']
x_pos = list(range(len(x_vals)))

def plot_if_exists(df, label, color):
    xs = []
    ys = []

    for i, x in enumerate(x_vals):
        if x in df.index:
            xs.append(i)
            ys.append(df.loc[x, 'KNN (k=10, euclidean)'])

    ax.plot(xs, ys, marker='o', label=label, color=color)

plot_if_exists(evals_df_eqres, 'EqResNet18', 'orange')
plot_if_exists(evals_df_res, 'ResNet18', 'blue')

ax.set_xticks(x_pos)
ax.set_xticklabels(x_vals)

ax.set_ylim(0.75, 0.91)
ax.tick_params(axis='both', which='major', labelsize=size-2)
ax.spines['left'].set_position(('outward', 10)) 

ax.set_xlabel("Percentage of training samples", fontsize=size)
ax.set_ylabel("KNN Accuracy", fontsize=size)
ax.legend(frameon=False, loc='lower right', fontsize=size)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
